# %%
import requests
import json
import pandas as pd
import csv
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import pandas as pd
#       4 import csv
# ----> 5 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %% [markdown]
# # Extraction Layer

# %%
url = "https://realty-mole-property-api.p.rapidapi.com/randomProperties"

querystring = {"limit":"100000"}

headers = {
	"x-rapidapi-key": "c5a2e08edbmsh497a1c43b8c877fp1af99ajsna64cb4c4a2c8",
	"x-rapidapi-host": "realty-mole-property-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())

data = response.json()

# Save the date to a file
filename = 'PropertyRecords.json'
with open(filename, 'w') as file:
    json.dump(data,file, indent=4)

# %%
# Read into a Dataframe
propertyrecords_df = pd.read_json('PropertyRecords.json')

# %%
propertyrecords_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   addressLine1      500 non-null    object
#  1   city              500 non-null    object
#  2   state             500 non-null    object
#  3   zipCode           500 non-null    int64
#  4   formattedAddress  500 non-null    object
#  5   assessorID        349 non-null    object
#  6   bedrooms          323 non-null    float64
#  7   county            500 non-null    object
#  8   legalDescription  336 non-null    object
#  9   squareFootage     360 non-null    float64
#  10  subdivision       292 non-null    object
#  11  yearBuilt         345 non-null    float64
#  12  zoning            168 non-null    object
#  13  bathrooms         349 non-null    float64
#  14  lotSize           339 non-null    float64
#  15  propertyType      397 non-null    object
#  16  lastSalePrice     260 non-null    float64
#  17  lastSaleDate      316 non-null    object
#  18  features          460 non-null    object
#  19  taxAssessment     342 non-null    object
#  20  propertyTaxes     333 non-null    object
#  21  ownerOccupied     314 non-null    float64
#  22  owner             345 non-null    object
#  23  id                500 non-null    object
#  24  longitude         500 non-null    float64
#  25  latitude          500 non-null    float64
#  26  addressLine2      104 non-null    object
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %%
propertyrecords_df.head(50)
# Out:
#             addressLine1                city state  zipCode  \
# 0       2523 Anderson Rd          Burlington    NC    27217
# 1         7300 Wayne Ave         Miami Beach    FL    33141
# 2      3558 Headwater Dr             Vallejo    CA    94591
# 3         824 28th Ave S             Seattle    WA    98144
# 4             47 Pope St          Providence    RI     2909
# 5              241 S Ave         Los Angeles    CA    90042
# 6      14206 Avalon Path           Rosemount    MN    55068
# 7        1926 Evening Dr             Augusta    GA    30906
# 8           202 Fleet Ct               Bronx    NY    10473
# 9    812 Gabe Holcomb Rd             Brandon    MS    39042
# 10       3111 Ne 51st St     Fort Lauderdale    FL    33308
# 11           208 14th St           Levelland    TX    79336
# 12  12204 Carmel Hill Ln            Pearland    TX    77584
# 13        3331 W Polk St             Chicago    IL    60624
# 14            511 W C St        Elizabethton    TN    37643
# 15      216 Tahitian Way              Destin    FL    32541
# 16          441 W 5th St              Oxnard    CA    93030
# 17       2833 Emmons Ave     North Las Vegas    NV    89030
# 18          206 James St           Leechburg    PA    15656
# 19        102-55 67th Dr        Forest Hills    NY    11375
# 20         537 Beaver St           Leetsdale    PA    15056
# 21        131 Hampton Ct          Northville    MI    48168
# 22        1501 N 31st St        Philadelphia    PA    19121
# 23      2583 N Wister Ln                Lehi    UT    84043
# 24      15845 Calumet Ct           Riverside    CA    92506
# 25      2303 Perkins Ave        Mount Vernon    IL    62864
# 26         3445 Lacon Rd            Hilliard    OH    43026
# 27   132 Mount Olivet Dr       Winston Salem    NC    27107
# 28    965 E Macarthur St              Sonoma    CA    95476
# 29           233 27th St         Miami Beach    FL    33140
# 30    1360 Goldenwood Dr          West Fargo    ND    58078
# 31        289 Toxaway Dr        Lake Toxaway    NC    28747
# 32               23rd St          Batesville    AR    72501
# 33         239 Sunset Ln            Hiawatha    IA    52233
# 34     2108 Fulton Dr NW          Huntsville    AL    35810
# 35          223 E 8th St              Harper    KS    67058
# 36   1947 Walter Raleigh           Windcrest    TX    78239
# 37           227 Reed St           Stratford    CT     6614
# 38  16726 Lilly Crest Dr         San Antonio    TX    78232
# 39        100 Tijuana Dr  Buenaventura Lakes    FL    34743
# 40     806 Cottonwood St          Jourdanton    TX    78026
# 41        4781 Abbott Rd        Orchard Park    NY    14127
# 42       119 Carriage Ln         Summerville    SC    29486
# 43     115 Crownpoint Rd        Williamsburg    VA    23185
# 44    6550 Bellaire Blvd             Houston    TX    77074
# 45           699 N 600 E               Logan    UT    84321
# 46  4057 Belle Meade Cir             Belmont    NC    28012
# 47  2002 Gallows Tree Ct              Vienna    VA    22182
# 48      1012 Clarence Dr        Natchitoches    LA    71457
# 49    1621 E Mcdowell Rd             Phoenix    AZ    85006
#
#                                      formattedAddress  \
# 0              2523 Anderson Rd, Burlington, NC 27217
# 1      7300 Wayne Ave, Apt 204, Miami Beach, FL 33141
# 2                3558 Headwater Dr, Vallejo, CA 94591
# 3                   824 28th Ave S, Seattle, WA 98144
# 4                    47 Pope St, Providence, RI 02909
# 5        241 S Ave, 57 Apt 201, Los Angeles, CA 90042
# 6              14206 Avalon Path, Rosemount, MN 55068
# 7                  1926 Evening Dr, Augusta, GA 30906
# 8                       202 Fleet Ct, Bronx, NY 10473
# 9              812 Gabe Holcomb Rd, Brandon, MS 39042
# 10  3111 Ne 51st St, Apt 203, Fort Lauderdale, FL ...
# 11                   208 14th St, Levelland, TX 79336
# 12           12204 Carmel Hill Ln, Pearland, TX 77584
# 13                  3331 W Polk St, Chicago, IL 60624
# 14                 511 W C St, Elizabethton, TN 37643
# 15                 216 Tahitian Way, Destin, FL 32541
# 16                     441 W 5th St, Oxnard, CA 93030
# 17         2833 Emmons Ave, North Las Vegas, NV 89030
# 18                  206 James St, Leechburg, PA 15656
# 19    102-55 67th Dr, Unit 6K, Forest Hills, NY 11375
# 20                 537 Beaver St, Leetsdale, PA 15056
# 21               131 Hampton Ct, Northville, MI 48168
# 22    1501 N 31st St, Apt 302, Philadelphia, PA 19121
# 23                   2583 N Wister Ln, Lehi, UT 84043
# 24              15845 Calumet Ct, Riverside, CA 92506
# 25           2303 Perkins Ave, Mount Vernon, IL 62864
# 26                  3445 Lacon Rd, Hilliard, OH 43026
# 27       132 Mount Olivet Dr, Winston Salem, NC 27107
# 28               965 E Macarthur St, Sonoma, CA 95476
# 29         233 27th St, Apt 2A, Miami Beach, FL 33140
# 30           1360 Goldenwood Dr, West Fargo, ND 58078
# 31             289 Toxaway Dr, Lake Toxaway, NC 28747
# 32                      23rd St, Batesville, AR 72501
# 33                  239 Sunset Ln, Hiawatha, IA 52233
# 34            2108 Fulton Dr NW, Huntsville, AL 35810
# 35                     223 E 8th St, Harper, KS 67058
# 36           1947 Walter Raleigh, Windcrest, TX 78239
# 37                   227 Reed St, Stratford, CT 06614
# 38        16726 Lilly Crest Dr, San Antonio, TX 78232
# 39       100 Tijuana Dr, Buenaventura Lakes, FL 34743
# 40            806 Cottonwood St, Jourdanton, TX 78026
# 41             4781 Abbott Rd, Orchard Park, NY 14127
# 42             119 Carriage Ln, Summerville, SC 29486
# 43          115 Crownpoint Rd, Williamsburg, VA 23185
# 44    6550 Bellaire Blvd, Apt 112A, Houston, TX 77074
# 45                       699 N 600 E, Logan, UT 84321
# 46            4057 Belle Meade Cir, Belmont, NC 28012
# 47             2002 Gallows Tree Ct, Vienna, VA 22182
# 48           1012 Clarence Dr, Natchitoches, LA 71457
# 49              1621 E Mcdowell Rd, Phoenix, AZ 85006
#
#                  assessorID  bedrooms               county  \
# 0                    155039       3.0             Alamance
# 1          02-3202-093-0130       2.0           Miami-Dade
# 2              0081-851-150       4.0               Solano
# 3               042404-9057       2.0                 King
# 4           PROV M:63 L:282       7.0           Providence
# 5              5492-004-109       1.0          Los Angeles
# 6           34-14703-11-904       2.0               Dakota
# 7            133-3-081-00-0       2.0      Richmond County
# 8                 034321258       NaN                Bronx
# 9          Q02 000034 00020       3.0               Rankin
# 10                      NaN       NaN              Broward
# 11                    11132       NaN              Hockley
# 12            7708-9101-007       NaN             Brazoria
# 13            16-14-414-026       3.0                 Cook
# 14          010041H C 01300       4.0               Carter
# 15  00-2S-22-1125-0000-0060       4.0             Okaloosa
# 16                      NaN       NaN              Ventura
# 17           139-24-311-079       2.0                Clark
# 18                      NaN       4.0            Armstrong
# 19                      NaN       2.0               Queens
# 20                704-L-201       2.0            Allegheny
# 21       48 003 05 0029 000       3.0                Wayne
# 22                      NaN       NaN         Philadelphia
# 23              41-897-0312       3.0                 Utah
# 24              245-350-008       4.0            Riverside
# 25            07-31-326-004       2.0            Jefferson
# 26               050-002531       3.0             Franklin
# 27          6832-61-7699.00       3.0             Davidson
# 28          128-111-005-000       1.0               Sonoma
# 29                      NaN       NaN           Miami-Dade
# 30           02071900270000       3.0                 Cass
# 31                      NaN       NaN         Transylvania
# 32                      NaN       NaN  Independence County
# 33        FH-10-0-40-2  - -       NaN                 Linn
# 34   14-08-27-2-003-056.000       NaN              Madison
# 35  081-01-0-40-19-001.00-0       3.0               Harper
# 36           05960-401-0360       4.0                Bexar
# 37   STRA M:50-13 B:26 L:11       3.0            Fairfield
# 38           14813-009-0250       3.0                Bexar
# 39                      NaN       3.0              Osceola
# 40                   R24351       NaN             Atascosa
# 41     146089 171.16-4-10.1       2.0                 Erie
# 42            221-11-02-025       3.0             Berkeley
# 43           49-1 02-5-0006       NaN           James City
# 44                      NaN       NaN               Harris
# 45                      NaN       9.0                Cache
# 46                   190197       4.0               Gaston
# 47            039-2-31-0077       3.0              Fairfax
# 48               0011384590       NaN         Natchitoches
# 49                      NaN       NaN             Maricopa
#
#                                      legalDescription  squareFootage  ...  \
# 0           ROBIN HEIGHTS SUBD SECT 1 LT 20 13-24A-69         1080.0  ...
# 1   PARKVIEW PLAZA CONDO UNIT 204 UNDIV .013% INT ...         1073.0  ...
# 2   RM BK 69 PG 100 LT 17 UN 4 NORTHGATE NEIGHBORH...         3230.0  ...
# 3   POR SE 1/4 LY E OF 28TH AVE S & W OF BLK 7 BAX...         3100.0  ...
# 4                    LOT:282 CITY/MUNI/TWP:PROVIDENCE         2168.0  ...
# 5   POR BLK 9 MB 2-69-70,MB 10-177 CONDO UNIT 201 ...          633.0  ...
# 6   2 4 CIC #367 BLOOMFIELD QUAD TOWNHOMES UNIT #1...         1698.0  ...
# 7                          SILVER CREST (00000) 014-J          950.0  ...
# 8                                                 NaN         1377.0  ...
# 9              1.3 AC IN NE4 SE4 E OF GABE HOLCOMB RD         1689.0  ...
# 10                                                NaN            NaN  ...
# 11    C M ELDER (LEV), BLOCK 7, LOT 4 ALL & LOT 5 E/2         1701.0  ...
# 12  SOUTHERN TRAILS PH 1 SEC 9A (0564 HT&B)(PEARLA...         2887.0  ...
# 13  DIST:77 CITY/MUNI/TWP:WEST CHICAGO SEC/TWN/RNG...         2295.0  ...
# 14              DISTRICT: 15 LOT 16, COUNTY AREA: F03         1360.0  ...
# 15                    VILLAGES OF CRYSTAL BEACH LOT 6         1939.0  ...
# 16                                                NaN            NaN  ...
# 17  COLLEGE PARK #09 PLAT BOOK 5 PAGE 30 LOT 16 BL...         1223.0  ...
# 18                                                NaN            NaN  ...
# 19                                                NaN            NaN  ...
# 20  VICTORY TERR PLAN PT 4 LOT 26.67X92.5X26.70 RR...          900.0  ...
# 21  03W29 UNIT 29 REPLAT NO 1 WAYNE COUNTY COND SU...         2044.0  ...
# 22                                                NaN            NaN  ...
# 23  LOT 312, PLAT B, HOLBROOK FARMS, PHASE 3 SUB A...         2095.0  ...
# 24         2.74 ACRES NET IN LOT 4 MB 091/075 TR 8633         1952.0  ...
# 25            CITY PARK ADD 50' MID PT LOTS 369 & 370          730.0  ...
# 26                          3445 LACON BEACON LOT 100         1200.0  ...
# 27                                      LO046 BL2712B         1889.0  ...
# 28                                                NaN         1864.0  ...
# 29                                                NaN            NaN  ...
# 30  GOLDENWOOD 5TH LT 27 BLK 1 **8-5-14 PER PLAT D...         1662.0  ...
# 31                                                NaN            NaN  ...
# 32                                                NaN            NaN  ...
# 33   FOTS 1995 TITLE #57AH 81704PARK: MHP91 - SU NSET            NaN  ...
# 34                 LOT 2 BLK 5 SHADY LANE PB 1 PG 365         1124.0  ...
# 35              CITY OF HARPER, BLOCK 19, LOT 001 & 2          956.0  ...
# 36  CB 5960D BLK 1 LOT 36 WINN BROOKS ESTATES SUBD...         2752.0  ...
# 37              LOT:11 BLK:26 CITY/MUNI/TWP:STRATFORD         1190.0  ...
# 38                           NCB 14813 BLK 009 LOT 25         1537.0  ...
# 39                                                NaN         1090.0  ...
# 40            JOURDANTON BLK 201 LOT 2, 4, 6, 8 MH MH         1008.0  ...
# 41  LOT:10.100 BLK:4 SEC:171.160 DIST:146089 CITY/...         1313.0  ...
# 42                    ASSESSMENT DISTRICT: 650TRAMWAY         1380.0  ...
# 43                                 L-6 S-5 KINGSPOINT         2902.0  ...
# 44                                                NaN            NaN  ...
# 45                                                NaN            NaN  ...
# 46                 BELLE MEADE L 88 15 071 001 86 000         2540.0  ...
# 47                          HAHN PROPERTY LT 77 SEC 2         1560.0  ...
# 48  LOT 7 OF BRIARWOOD SUBDIVISION, UNIT 1 IN SEC....            NaN  ...
# 49                                                NaN            NaN  ...
#
#                 lastSaleDate  \
# 0   2015-06-23T00:00:00.000Z
# 1   1997-12-24T00:00:00.000Z
# 2   2003-07-16T00:00:00.000Z
# 3   2009-08-10T00:00:00.000Z
# 4   2012-09-14T00:00:00.000Z
# 5   2023-02-23T00:00:00.000Z
# 6   2015-04-15T00:00:00.000Z
# 7   2017-02-28T00:00:00.000Z
# 8                        NaN
# 9   2019-10-08T00:00:00.000Z
# 10                       NaN
# 11                       NaN
# 12  2012-03-28T00:00:00.000Z
# 13  2006-03-13T00:00:00.000Z
# 14  2023-07-10T00:00:00.000Z
# 15  2019-01-15T00:00:00.000Z
# 16  2021-11-08T00:00:00.000Z
# 17  2018-02-12T00:00:00.000Z
# 18                       NaN
# 19                       NaN
# 20  2012-10-15T00:00:00.000Z
# 21  2018-09-12T00:00:00.000Z
# 22  2019-12-02T00:00:00.000Z
# 23  2021-04-23T00:00:00.000Z
# 24                       NaN
# 25  2022-06-24T00:00:00.000Z
# 26  2001-03-27T00:00:00.000Z
# 27  2019-12-09T00:00:00.000Z
# 28                       NaN
# 29                       NaN
# 30  2023-03-28T00:00:00.000Z
# 31                       NaN
# 32                       NaN
# 33                       NaN
# 34                       NaN
# 35                       NaN
# 36  2021-07-02T00:00:00.000Z
# 37  2008-12-12T00:00:00.000Z
# 38  2017-12-07T00:00:00.000Z
# 39  1986-01-01T00:00:00.000Z
# 40  2001-10-11T00:00:00.000Z
# 41  2007-03-23T00:00:00.000Z
# 42  1982-11-22T00:00:00.000Z
# 43                       NaN
# 44                       NaN
# 45  2020-07-17T00:00:00.000Z
# 46  2018-08-31T00:00:00.000Z
# 47  2016-02-19T00:00:00.000Z
# 48  2021-06-07T00:00:00.000Z
# 49  2016-02-04T00:00:00.000Z
#
#                                              features  \
# 0   {'architectureType': 'Ranch', 'cooling': True,...
# 1   {'architectureType': 'Condo / Apartment', 'uni...
# 2   {'cooling': True, 'coolingType': 'Central', 'f...
# 3   {'architectureType': 'Multi-Unit Building', 'c...
# 4   {'architectureType': 'Other', 'exteriorType': ...
# 5   {'architectureType': 'Condo / Apartment', 'hea...
# 6   {'floorCount': 2, 'garage': True, 'garageType'...
# 7   {'cooling': True, 'coolingType': 'Central', 'e...
# 8   {'architectureType': 'Condo / Apartment', 'flo...
# 9   {'cooling': True, 'coolingType': 'Commercial',...
# 10                                                 {}
# 11                                                 {}
# 12  {'cooling': True, 'coolingType': 'Central', 'e...
# 13  {'architectureType': 'Split Level', 'cooling':...
# 14  {'cooling': True, 'coolingType': 'Commercial',...
# 15  {'cooling': True, 'coolingType': 'Central', 'e...
# 16                                                 {}
# 17  {'architectureType': 'Single Story', 'cooling'...
# 18                                                 {}
# 19                                                NaN
# 20  {'architectureType': 'Condo / Apartment', 'ext...
# 21  {'architectureType': 'Split Level', 'cooling':...
# 22                                                 {}
# 23  {'architectureType': 'A-Frame', 'cooling': Tru...
# 24  {'cooling': True, 'coolingType': 'Central', 'f...
# 25                                                 {}
# 26  {'architectureType': 'Ranch', 'cooling': True,...
# 27  {'architectureType': 'Conventional', 'cooling'...
# 28  {'cooling': True, 'coolingType': 'Commercial',...
# 29                                                 {}
# 30                                                 {}
# 31                                                 {}
# 32                                                NaN
# 33  {'architectureType': 'Mobile Home', 'unitCount...
# 34  {'cooling': True, 'coolingType': 'Commercial',...
# 35  {'exteriorType': 'Aluminum / Vinyl Siding', 'f...
# 36  {'architectureType': 'Contemporary', 'cooling'...
# 37  {'architectureType': 'Colonial', 'cooling': Tr...
# 38  {'architectureType': 'Contemporary', 'cooling'...
# 39                                                NaN
# 40                                                 {}
# 41  {'architectureType': 'Traditional', 'exteriorT...
# 42  {'fireplace': True, 'fireplaceType': 'Prefab',...
# 43  {'cooling': True, 'coolingType': 'Central', 'e...
# 44                                                 {}
# 45                                                NaN
# 46  {'architectureType': 'Custom', 'cooling': True...
# 47  {'architectureType': 'Split Level', 'cooling':...
# 48                {'architectureType': 'Mobile Home'}
# 49                                                 {}
#
#                                         taxAssessment  \
# 0   {'2022': {'value': 74967, 'land': 15000, 'impr...
# 1   {'2019': {'value': 98174}, '2022': {'value': 1...
# 2   {'2023': {'value': 703781, 'land': 170818, 'im...
# 3   {'2020': {'value': 1021000, 'land': 792000, 'i...
# 4   {'2019': {'value': 157600, 'land': 20800, 'imp...
# 5   {'2022': {'value': 305515, 'land': 189371, 'im...
# 6   {'2022': {'value': 256300, 'land': 63100, 'imp...
# 7   {'2020': {'value': 22865, 'land': 6400, 'impro...
# 8   {'2018': {'value': 34672, 'land': 23973, 'impr...
# 9                          {'2020': {'value': 11089}}
# 10                                                NaN
# 11  {'2022': {'value': 81530, 'land': 2920, 'impro...
# 12  {'2022': {'value': 382030, 'land': 62090, 'imp...
# 13  {'2022': {'value': 23999, 'land': 6704, 'impro...
# 14  {'2022': {'value': 35425, 'land': 8275, 'impro...
# 15  {'2021': {'value': 416542, 'land': 149940, 'im...
# 16                                                NaN
# 17  {'2021': {'value': 36125, 'land': 20300, 'impr...
# 18                                                NaN
# 19                                                NaN
# 20  {'2019': {'value': 48500, 'land': 11400, 'impr...
# 21                        {'2022': {'value': 174500}}
# 22                                                NaN
# 23  {'2022': {'value': 361075}, '2024': {'value': ...
# 24  {'2020': {'value': 179518, 'land': 134399, 'im...
# 25  {'2021': {'value': 5655, 'land': 1403, 'improv...
# 26  {'2021': {'value': 50270, 'land': 15790, 'impr...
# 27  {'2019': {'value': 131500, 'land': 22500, 'imp...
# 28  {'2022': {'value': 236414, 'land': 53354, 'imp...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                       {'2022': {}}
# 34  {'2020': {'value': 13200, 'land': 2420, 'impro...
# 35  {'2022': {'value': 968, 'land': 922, 'improvem...
# 36  {'2021': {'value': 280170, 'land': 53820, 'imp...
# 37  {'2021': {'value': 174300, 'land': 89670, 'imp...
# 38  {'2018': {'value': 197110, 'land': 44600, 'imp...
# 39                                                NaN
# 40                                                NaN
# 41  {'2019': {'value': 58000, 'land': 15400, 'impr...
# 42  {'2022': {'value': 4743, 'land': 847, 'improve...
# 43  {'2022': {'value': 376500, 'land': 122300, 'im...
# 44                                                NaN
# 45                                                NaN
# 46  {'2022': {'value': 309960, 'land': 46000, 'imp...
# 47  {'2022': {'value': 711210, 'land': 260000, 'im...
# 48  {'2022': {'value': 4820, 'land': 1220, 'improv...
# 49                                                NaN
#
#                                         propertyTaxes  ownerOccupied  \
# 0   {'2022': {'total': 858}, '2023': {'total': 1229}}            0.0
# 1    {'2019': {'total': 557}, '2022': {'total': 615}}            1.0
# 2                          {'2022': {'total': 10547}}            1.0
# 3   {'2020': {'total': 10086}, '2022': {'total': 1...            0.0
# 4   {'2019': {'total': 3616}, '2022': {'total': 47...            1.0
# 5   {'2022': {'total': 3599}, '2023': {'total': 37...            1.0
# 6                           {'2023': {'total': 2616}}            0.0
# 7                           {'2020': {'total': 1000}}            NaN
# 8                           {'2017': {'total': 3731}}            1.0
# 9                            {'2020': {'total': 778}}            1.0
# 10                                                NaN            NaN
# 11                                                NaN            1.0
# 12  {'2018': {'total': 10777}, '2022': {'total': 1...            1.0
# 13                          {'2022': {'total': 4953}}            1.0
# 14                          {'2022': {'total': 1275}}            1.0
# 15  {'2021': {'total': 5142}, '2022': {'total': 64...            0.0
# 16                                                NaN            NaN
# 17   {'2020': {'total': 711}, '2023': {'total': 893}}            1.0
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20  {'2019': {'total': 1607}, '2022': {'total': 16...            1.0
# 21                          {'2022': {'total': 6504}}            1.0
# 22                                                NaN            NaN
# 23  {'2022': {'total': 2927}, '2023': {'total': 26...            1.0
# 24  {'2020': {'total': 2398}, '2023': {'total': 24...            1.0
# 25                           {'2021': {'total': 550}}            1.0
# 26  {'2022': {'total': 3445}, '2023': {'total': 39...            1.0
# 27  {'2019': {'total': 1132}, '2020': {'total': 11...            0.0
# 28  {'2022': {'total': 3064}, '2023': {'total': 31...            1.0
# 29                                                NaN            NaN
# 30                                                NaN            NaN
# 31                                                NaN            NaN
# 32                                                NaN            NaN
# 33                           {'2021': {'total': 154}}            1.0
# 34  {'2020': {'total': 766}, '2022': {'total': 941...            0.0
# 35                                                NaN            NaN
# 36  {'2021': {'total': 6741}, '2022': {'total': 76...            1.0
# 37  {'2021': {'total': 6880}, '2022': {'total': 68...            1.0
# 38  {'2019': {'total': 2962}, '2022': {'total': 30...            1.0
# 39                                                NaN            NaN
# 40                                                NaN            NaN
# 41                          {'2016': {'total': 3082}}            1.0
# 42                           {'2022': {'total': 485}}            1.0
# 43                          {'2021': {'total': 2922}}            1.0
# 44                                                NaN            NaN
# 45                                                NaN            NaN
# 46                          {'2022': {'total': 1500}}            1.0
# 47  {'2022': {'total': 8133}, '2023': {'total': 81...            1.0
# 48                           {'2022': {'total': 377}}            NaN
# 49                                                NaN            NaN
#
#                                                 owner  \
# 0   {'names': ['Montonio Johnson'], 'mailingAddres...
# 1   {'names': ['HAYDEE I GARAY'], 'mailingAddress'...
# 2   {'names': ['Connell E Gainous', 'CONNELL ANNIE...
# 3   {'names': ['MRN HOMES LLC'], 'mailingAddress':...
# 4   {'names': ['Ana A Figueroa'], 'mailingAddress'...
# 5   {'names': ['John Carlos Roman'], 'mailingAddre...
# 6   {'names': ['Investmentsllc Legacy'], 'type': '...
# 7   {'names': ['HALKEN INVESTMENT PROPERTIES O'], ...
# 8   {'names': [''], 'mailingAddress': {'id': '202-...
# 9   {'names': ['CHARLES FREEMAN'], 'mailingAddress...
# 10                                                NaN
# 11  {'names': ['SHERRON JOHNSON'], 'mailingAddress...
# 12  {'names': ['Roy Libutaque', 'Ruth Libutaque'],...
# 13  {'names': ['MARVIN L SCOTT'], 'mailingAddress'...
# 14  {'names': ['TAYLOR MOOREFIELD', 'HEATHER MOORE...
# 15  {'names': ['Steven Douglas Tintzman', 'Cheryl ...
# 16                                                NaN
# 17  {'names': ['Todd Mitchell Payne', 'Patricia Pa...
# 18                                                NaN
# 19                                                NaN
# 20  {'names': ['MICHAEL SCHNURER'], 'mailingAddres...
# 21  {'names': ['JOSEPH FENNELL', 'JOYCE FENNELL'],...
# 22                                                NaN
# 23  {'names': ['Jose Maynor Melendez', 'Angela Mel...
# 24  {'names': ['Griffin G L & L Family Trust'], 'm...
# 25  {'names': ['Adam J Brazell'], 'mailingAddress'...
# 26  {'names': ['GRETCHEN L GFELL'], 'mailingAddres...
# 27  {'names': ['ALTO ASSET CO 1 LLC'], 'mailingAdd...
# 28  {'names': ['WEBER LARRY C TRUST & WEBER MARY A...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  {'names': ['SHERRY LEE SACKETT'], 'mailingAddr...
# 34  {'names': ['COACH STAFFORD LLC'], 'mailingAddr...
# 35  {'names': ['MICKY D MCCANN', 'JESSECA D MCCANN...
# 36  {'names': ['Joshua Dane Sturm'], 'mailingAddre...
# 37  {'names': ['Joe C Davis', 'Elizabeth B Davis']...
# 38  {'names': ['Sharon R Robinson'], 'mailingAddre...
# 39                                                NaN
# 40                                    {'names': ['']}
# 41  {'names': ['Nicole M Galley', 'Howard J Willso...
# 42  {'names': ['HERBERT M MORRIS', 'VICKIE O MORRI...
# 43  {'names': ['EUGENE A MORELLI'], 'mailingAddres...
# 44                                                NaN
# 45                                                NaN
# 46  {'names': ['JAMES RICHARD BLINCK', 'PAMELA ANN...
# 47  {'names': ['Alyce Dilauro', 'Brett G Warren'],...
# 48  {'names': ['JHAT, LLC'], 'mailingAddress': {'i...
# 49                                                NaN
#
#                                                    id   longitude   latitude  \
# 0              2523-Anderson-Rd,-Burlington,-NC-27217  -79.345055  36.126189
# 1      7300-Wayne-Ave,-Apt-204,-Miami-Beach,-FL-33141  -80.127012  25.858310
# 2                3558-Headwater-Dr,-Vallejo,-CA-94591 -122.205007  38.129402
# 3                   824-28th-Ave-S,-Seattle,-WA-98144 -122.296329  47.594991
# 4                    47-Pope-St,-Providence,-RI-02909  -71.448132  41.823029
# 5        241-S-Ave,-57-Apt-201,-Los-Angeles,-CA-90042 -118.192134  34.105894
# 6              14206-Avalon-Path,-Rosemount,-MN-55068  -93.103830  44.742832
# 7                  1926-Evening-Dr,-Augusta,-GA-30906  -82.024688  33.388852
# 8                       202-Fleet-Ct,-Bronx,-NY-10473  -73.852354  40.806762
# 9              812-Gabe-Holcomb-Rd,-Brandon,-MS-39042  -89.757381  32.096659
# 10  3111-Ne-51st-St,-Apt-203,-Fort-Lauderdale,-FL-...  -80.104894  26.191062
# 11                   208-14th-St,-Levelland,-TX-79336 -102.369909  33.578236
# 12           12204-Carmel-Hill-Ln,-Pearland,-TX-77584  -95.410120  29.547808
# 13                  3331-W-Polk-St,-Chicago,-IL-60624  -87.710015  41.870600
# 14                 511-W-C-St,-Elizabethton,-TN-37643  -82.234025  36.348531
# 15                 216-Tahitian-Way,-Destin,-FL-32541  -86.420881  30.387061
# 16                     441-W-5th-St,-Oxnard,-CA-93030 -119.181950  34.197855
# 17         2833-Emmons-Ave,-North-Las-Vegas,-NV-89030 -115.108589  36.194738
# 18                  206-James-St,-Leechburg,-PA-15656  -79.618177  40.633959
# 19    102-55-67th-Dr,-Unit-6K,-Forest-Hills,-NY-11375  -73.849780  40.727048
# 20                 537-Beaver-St,-Leetsdale,-PA-15056  -80.205007  40.563125
# 21               131-Hampton-Ct,-Northville,-MI-48168  -83.484131  42.424693
# 22    1501-N-31st-St,-Apt-302,-Philadelphia,-PA-19121  -75.185239  39.979614
# 23                   2583-N-Wister-Ln,-Lehi,-UT-84043 -111.920529  40.419013
# 24              15845-Calumet-Ct,-Riverside,-CA-92506 -117.376582  33.890886
# 25           2303-Perkins-Ave,-Mount-Vernon,-IL-62864  -88.918571  38.307038
# 26                  3445-Lacon-Rd,-Hilliard,-OH-43026  -83.137183  40.023262
# 27       132-Mount-Olivet-Dr,-Winston-Salem,-NC-27107  -80.227964  36.001605
# 28               965-E-Macarthur-St,-Sonoma,-CA-95476 -122.441588  38.282510
# 29         233-27th-St,-Apt-2A,-Miami-Beach,-FL-33140  -80.126191  25.804163
# 30           1360-Goldenwood-Dr,-West-Fargo,-ND-58078  -96.910217  46.896750
# 31             289-Toxaway-Dr,-Lake-Toxaway,-NC-28747  -82.960000  35.135276
# 32                      23rd-St,-Batesville,-AR-72501  -91.627630  35.775012
# 33                  239-Sunset-Ln,-Hiawatha,-IA-52233  -91.677129  42.043759
# 34            2108-Fulton-Dr-NW,-Huntsville,-AL-35810  -86.623050  34.754105
# 35                     223-E-8th-St,-Harper,-KS-67058  -98.024414  37.288738
# 36           1947-Walter-Raleigh,-Windcrest,-TX-78239  -98.364939  29.524494
# 37                   227-Reed-St,-Stratford,-CT-06614  -73.123566  41.212606
# 38        16726-Lilly-Crest-Dr,-San-Antonio,-TX-78232  -98.468410  29.595603
# 39       100-Tijuana-Dr,-Buenaventura-Lakes,-FL-34743  -81.366386  28.321877
# 40            806-Cottonwood-St,-Jourdanton,-TX-78026  -98.555760  28.933493
# 41             4781-Abbott-Rd,-Orchard-Park,-NY-14127  -78.793827  42.753797
# 42             119-Carriage-Ln,-Summerville,-SC-29486  -80.144047  33.049559
# 43          115-Crownpoint-Rd,-Williamsburg,-VA-23185  -76.704644  37.241354
# 44    6550-Bellaire-Blvd,-Apt-112A,-Houston,-TX-77074  -95.498057  29.705494
# 45                       699-N-600-E,-Logan,-UT-84321 -111.819427  41.744242
# 46            4057-Belle-Meade-Cir,-Belmont,-NC-28012  -81.033129  35.206108
# 47             2002-Gallows-Tree-Ct,-Vienna,-VA-22182  -77.224608  38.907797
# 48           1012-Clarence-Dr,-Natchitoches,-LA-71457  -93.070996  31.735927
# 49              1621-E-Mcdowell-Rd,-Phoenix,-AZ-85006 -112.046612  33.465631
#
#    addressLine2
# 0           NaN
# 1       Apt 204
# 2           NaN
# 3           NaN
# 4           NaN
# 5    57 Apt 201
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10      Apt 203
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19      Unit 6K
# 20          NaN
# 21          NaN
# 22      Apt 302
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29       Apt 2A
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44     Apt 112A
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
#
# [50 rows x 27 columns]
